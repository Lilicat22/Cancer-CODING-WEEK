# %%
from src.data_processing_XGBoost import optimize_memory
import pandas as pd

df = pd.read_csv("data/cancer_data.csv")

# Avant optimisation
print("Before optimization")
print(df.info(memory_usage='deep'))

# Optimisation
df = optimize_memory(df)

# Après optimisation
print("After optimization")
print(df.info(memory_usage='deep'))
# Out:
# Project path added: c:\Users\Utilisateur\Documents\GitHub\Cancer-CODING-WEEK\notebooks
