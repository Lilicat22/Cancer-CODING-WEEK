# %%
import sys
sys.path.append('../src')

# %%
import joblib 
import matplotlib.pyplot as pyplot
import shap
from sklearn.metrics import confusion_matrix,classifiication_report, confusionMatrixDisplay
from data_processing_SVM import load_data

# %%
model = joblib.load('../model/xgboost_model.pkl')

X_train, X_test, y_train, y_test = load_data()

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# SHAP : importance des features (bar chart)
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_test)   # nouvelle API SHAP
shap.plots.bar(shap_values, max_display=10, show=False)  # top 10 features
plt.tight_layout()
plt.savefig(data_dir / "shap_summary_bar_plot.png")
plt.close()

return y_pred
